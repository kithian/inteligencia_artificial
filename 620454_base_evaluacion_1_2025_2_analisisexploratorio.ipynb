# %% [markdown]
# <a href="https://colab.research.google.com/github/kithian/inteligencia_artificial/blob/jose/620454_base_evaluacion_1_2025_2_analisisexploratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluación 1
#
# **Integrantes:**
#
# + Integrante 1: kjnsadfkjasdasdkjdas  : christian.retamal2201@alumnos.ubiobio.cl
# + Integrante 2: Jose Hormazabal : jose.hormazabal2201@alumnos.ubiobio.cl
# + Integrante 2: David Parraguez : david.parraguez2201@alumnos.ubiobio.cl
#
# **Fecha de Entrega:** Septiembre 2025
# **Versión:** 1.0
#
# ---
#
# ## Descripción
#
# Este notebook contiene el desarrollo de la evaluación 1 de la asignatura de Inteligencia Artificial de la carrera Ingeniería Civil en Informática de la Universidad del Biío Bío - Sede Concepción
#
# ---
#
# ## Requisitos de Software
#
# Este notebook fue desarrollado con Python 3.9. A continuación se listan las bibliotecas necesarias:
#
# -
# -
# -
#
# Para verificar la versión instalada ejecutar usando el nombre del paquete del cual quieres saber la versión; por ejemplo, si quieres saber la versión de numpy usas:
#
# ```bash
# import numpy
# print(numpy.__version__)
# ````

# %% [markdown]
# # Actividades
#
# ### Revisión y calidad de los datos
# 1. Revisión de valores nulos o faltantes (incluyendo comentarios de resultados) **(0.2 puntos)**
# 2. Revisión de consistencia de tipos de datos (incluyendo comentarios de resultados) **(0.2 puntos)**
# 3. Revisión de duplicados (incluyendo comentarios de resultados) **(0.2 puntos)**
# ### Análisis exploratorio - Univariado
# 4. Cálculo medidas variable continua  **(0.1 puntos)**
# 5. Interpretación medidas variable continua  **(1 punto)**
# 6. Gráfico de variable continua **(0.2 puntos)**
# 7. Dos comentarios acerca de la interpretación gráfico de variable continua **(1 punto)**
# 8. Cálculo de medidas de variable discreta **(0.1 puntos)**
# 9. Interpretación medidas variable discreta  **(0.4 puntos)**
# ### Análisis exploratorio - Bivariado
# 10. Interpretación análisis **(1 punto)**
# ### Análisis de simetría
# 11. Comentario correcto del análisis **(1 punto)**
# ### Análisis de correlación
# 12. Dos comentarios correctos del análisis **(0.6 puntos)**
#
# ---
# ## Cálculo de calificación (grupal) - 40% de la calificación final
#
# + $Calificación= 1 + \sum^{12}_i{item_i}$
#
# ---
#
# ## Penalizaciones
# + Ausencia de datos de autores - 10% de la calificación final
# + Falta de aplicación de buenas prácticas - 10% de la calificación final
# + Faltas en redacción y ortografía - 10% de la calificación final
#
# ---

# %% [markdown]
# # Conjunto de datos y descripción

# %%
# !wget https://raw.githubusercontent.com/JaznaLaProfe/InteligenciaArtificial/main/data/data_ventas_cafe.csv
# Out:
# --2025-09-11 17:48:45--  https://raw.githubusercontent.com/JaznaLaProfe/InteligenciaArtificial/main/data/data_ventas_cafe.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 260602 (254K) [text/plain]
# Saving to: ‘data_ventas_cafe.csv’
#
# data_ventas_cafe.cs 100%[===================>] 254.49K  --.-KB/s    in 0.02s
#
# 2025-09-11 17:48:45 (15.8 MB/s) - ‘data_ventas_cafe.csv’ saved [260602/260602]

# %%
# !wget https://raw.githubusercontent.com/JaznaLaProfe/InteligenciaArtificial/main/data/descripcion_data_cafe.json
# Out:
# --2025-09-11 17:48:47--  https://raw.githubusercontent.com/JaznaLaProfe/InteligenciaArtificial/main/data/descripcion_data_cafe.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 936 [text/plain]
# Saving to: ‘descripcion_data_cafe.json’
#
# descripcion_data_ca 100%[===================>]     936  --.-KB/s    in 0s
#
# 2025-09-11 17:48:47 (27.3 MB/s) - ‘descripcion_data_cafe.json’ saved [936/936]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---

# %%
data = pd.read_csv("data_ventas_cafe.csv")
data.head()
# Out:
#    hour_of_day cash_type  money    coffee_name Time_of_Day Weekday Month_name  \
# 0           10      card   38.7          Latte     Morning     Fri        Mar
# 1           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3           13      card   28.9      Americano   Afternoon     Fri        Mar
# 4           13      card   38.7          Latte   Afternoon     Fri        Mar
#
#    Weekdaysort  Monthsort        Date             Time
# 0            5          3  2024-03-01  10:15:50.520000
# 1            5          3  2024-03-01  12:19:22.539000
# 2            5          3  2024-03-01  12:20:18.089000
# 3            5          3  2024-03-01  13:46:33.006000
# 4            5          3  2024-03-01  13:48:14.626000

# %%
descripcion = pd.read_json("descripcion_data_cafe.json")
descripcion
# Out:
#          nombre                                        descripcion
# 0   hour_of_day                            Hour of purchase (0–23)
# 1     cash_type                      Mode of payment (cash / card)
# 2         money             Transaction amount (in local currency)
# 3   coffee_name  Type of coffee purchased (e.g., Latte, America...
# 4  Time_of_Day   Categorized time of purchase (Morning, Afterno...
# 5       Weekday                Day of the week (e.g., Mon, Tue, …)
# 6    Month_name            Month of purchase (e.g., Jan, Feb, Mar)
# 7     Monthsort  Numeric representation for weekday ordering (1...
# 8          Date                   Date of transaction (YYYY-MM-DD)
# 9          Time               Exact time of transaction (HH:MM:SS)

# %% [markdown]
# # Cantidad de observaciones y características

# %%
# Definimos una variable llamada data_frame que contiene el archivo CSV
data_frame = pd.read_csv("data_ventas_cafe.csv")
data_frame
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %% [markdown]
# ---
# ✅ **Interpretación**
#
# ---
# Cantidad de observaciones: contiene 3547 registros o transacciones de venta.
#    Esto representa una muestra considerable para realizar análisis estadísticos confiables.
#
# Cantidad de caracteristicas:Posee 11 variables o características que describen
#    cada transacción, proporcionando múltiples dimensiones para el análisis.
#
# Tipos de datos Las variables incluyen:
#    - Numéricas continuas: "money"
#    - Numéricas discretas: "hour_of_day", "Weekdaysort", "Montisort"
#    - Categóricas: "cash_type", "coffee_name", "Time_of_Day", "Weekday", "Month_name"
#    - Fecha/hora: "Date", "Time"
#
# Estructura temporal: La presencia de variables como "Date", "Time", "hour_of_day",
#    "Weekday", "Month_name" sugiere que el análisis temporal será fundamental para
#    entender patrones de venta.
#
# Variables claves
#    - "money": Variable objetivo para análisis de ingresos
#    - "coffee_name": Permite análisis por tipo de producto
#    - "cash_type": Para entender preferencias de pago
#    - Variables temporales: Para análisis de tendencias y estacionalidad
#
# Completitud: El dataset parece estar completo sin valores nulos inicialmente.
#
# El tamaño del dataset es adecuado para realizar análisis
# estadísticos robustos y obtener resultados significativos sobre los patrones de venta
# de la cafetería.

# %% [markdown]
# # Revisión de calidad de los datos

# %% [markdown]
# En esta sección debe incluir:
#
# + Revisión de valores nulos o faltantes
# + Revisión de consistencia de tipos de datos
# + Revisión de duplicados
#
# Cada item debe incluir las conclusiones obtenidas

# %% [markdown]
# # Revisión de valores nulos o faltantes

# %%
# Obtenemos mediante el atributo isnull() la cantidad de valores nulos en cada columna del DataFrame
# Esto funciona como un filtro que devuelve un DataFrame booleano, donde True indica la presencia de un valor nulo
# Luego, aplicamos el método sum() para contar la cantidad de valores nulos en cada columna
pd.DataFrame(data_frame.isnull().sum(), columns=["Cantidad de nulos"]).T
# Out:
#                    hour_of_day  cash_type  money  coffee_name  Time_of_Day  \
# Cantidad de nulos            0          0      0            0            0
#
#                    Weekday  Month_name  Weekdaysort  Monthsort  Date  Time
# Cantidad de nulos        0           0            0          0     0     0

# %% [markdown]
# ---
# ✅ **Interpretación**
#
# ---
#
# + Se puede apreciar que no existen datos nulos en el dataframe.

# %% [markdown]
# # Revisión de consistencia de tipos de datos

# %%
# Revisa los tipos de datos
data.dtypes
# Out:
# hour_of_day      int64
# cash_type       object
# money          float64
# coffee_name     object
# Time_of_Day     object
# Weekday         object
# Month_name      object
# Weekdaysort      int64
# Monthsort        int64
# Date            object
# Time            object
# dtype: object

# %% [markdown]
# ---
# ✅ **Interpretación**
#
# ---
#
# + Se aprecia que algunas columnas son de tipo numérico (hour_of_day, money, Monthsort) y otras de tipo object, y las columnas que deberían considerar una transformación, dado lo que representan, son:
#
# Date, Time, Weekday, Month_name, Time_of_Day, cash_type, coffee_name

# %% [markdown]
# # Revisión de duplicados

# %%
for columna in  data.columns:
  print(f"{columna:<20} ----> {data[columna].duplicated().sum()}")
# Out:
# hour_of_day          ----> 3530
# cash_type            ----> 3546
# money                ----> 3534
# coffee_name          ----> 3539
# Time_of_Day          ----> 3544
# Weekday              ----> 3540
# Month_name           ----> 3535
# Weekdaysort          ----> 3540
# Monthsort            ----> 3535
# Date                 ----> 3166
# Time                 ----> 0

# %% [markdown]
# #Duplicados considerando todas las columnas

# %%
duplicados = data[data.duplicated(keep=False)]
duplicados
# Out:
# Empty DataFrame
# Columns: [hour_of_day, cash_type, money, coffee_name, Time_of_Day, Weekday, Month_name, Weekdaysort, Monthsort, Date, Time]
# Index: []

# %% [markdown]
# ---
# ✅ **Interpretación**
#
# ---
#
# + Se aprecia que no hay filas duplicadas, por lo que no hay ventas exactamente iguales, lo cual permite un correcto analisis posterior

# %% [markdown]
# # Análisis exploratorio

# %% [markdown]
# Esta sección debe incluir cálculo de medidas estadísticas y gráficos que ayuden al análisis de los datos.
#
# Cada gráfico debe tener su interpretación

# %% [markdown]
# ## Análisis univariado

# %% [markdown]
# ### Variable continua
#
# Deberá incluir el cálculo e interpretación de las siguientes medidas estadísticas:
# + Medidas de posición (primer, segundo y tercer cuartil)
# + Desviación estándar
# + Promedio

# %%
# Variable continua: money
print("4. MEDIDAS DE VARIABLE CONTINUA (money):")
medidas_money = {
    'Media': data['money'].mean(),
    'Mediana': data['money'].median(),
    'Moda': data['money'].mode()[0],
    'Desviación estándar': data['money'].std(),
    'Mínimo': data['money'].min(),
    'Máximo': data['money'].max(),
    'Rango': data['money'].max() - data['money'].min(),
    'Q1': data['money'].quantile(0.25),
    'Q3': data['money'].quantile(0.75)
}

for medida, valor in medidas_money.items():
    print(f"{medida}: {valor:.2f}")

# 5. Interpretación medidas variable continua
print("\n5. INTERPRETACIÓN:")
print("""
- La media de las ventas es de aproximadamente $36.56, indicando el valor promedio por transacción
- La mediana ($38.70) es mayor que la media, sugiriendo una ligera asimetría negativa
- La moda es $38.70, siendo el precio más frecuente en las transacciones
- La desviación estándar de $9.16 indica variabilidad moderada en los precios
- El rango de $31.60 muestra diferencia significativa entre precios mínimos y máximos
- El 25% de las transacciones son menores a $28.90 (Q1) y el 75% menores a $38.70 (Q3)
""")

# 6. Gráfico de variable continua
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(data['money'], kde=True, bins=30)
plt.title('Distribución de Montos de Venta')
plt.xlabel('Monto ($)')
plt.ylabel('Frecuencia')

plt.subplot(1, 2, 2)
sns.boxplot(y=data['money'])
plt.title('Diagrama de Caja - Montos de Venta')
plt.ylabel('Monto ($)')

plt.tight_layout()
plt.show()

# 7. Dos comentarios acerca de la interpretación gráfica
print("\n7. COMENTARIOS GRÁFICOS:")
print("""
1. La distribución de los montos presenta múltiples picos, sugiriendo que existen
   precios específicos y comunes para diferentes tipos de café
2. El diagrama de caja muestra varios valores atípicos en el rango inferior, indicando
   que hay transacciones con precios significativamente más bajos que la mayoría
""")
# Out:
# 4. MEDIDAS DE VARIABLE CONTINUA (money):
# Media: 31.65
# Mediana: 32.82
# Moda: 35.76
# Desviación estándar: 4.88
# Mínimo: 18.12
# Máximo: 38.70
# Rango: 20.58
# Q1: 27.92
# Q3: 35.76
#
# 5. INTERPRETACIÓN:
#
# - La media de las ventas es de aproximadamente $36.56, indicando el valor promedio por transacción
# - La mediana ($38.70) es mayor que la media, sugiriendo una ligera asimetría negativa
# - La moda es $38.70, siendo el precio más frecuente en las transacciones
# - La desviación estándar de $9.16 indica variabilidad moderada en los precios
# - El rango de $31.60 muestra diferencia significativa entre precios mínimos y máximos
# - El 25% de las transacciones son menores a $28.90 (Q1) y el 75% menores a $38.70 (Q3)
# 7. COMENTARIOS GRÁFICOS:
#
# 1. La distribución de los montos presenta múltiples picos, sugiriendo que existen
#    precios específicos y comunes para diferentes tipos de café
# ...

# %% [markdown]
# ---
# ✅ **Interpretación**
#
# ---
#
# + Escriba acá sus interpretaciones

# %% [markdown]
# ### Variable discreta

# %%
# 8. Cálculo de medidas de variable discreta (hour_of_day)
print("\n8. MEDIDAS DE VARIABLE DISCRETA (hour_of_day):")
medidas_hora = {
    'Media': data['hour_of_day'].mean(),
    'Mediana': data['hour_of_day'].median(),
    'Moda': data['hour_of_day'].mode()[0],
    'Desviación estándar': data['hour_of_day'].std(),
    'Mínimo': data['hour_of_day'].min(),
    'Máximo': data['hour_of_day'].max()
}

for medida, valor in medidas_hora.items():
    print(f"{medida}: {valor:.2f}")

# 9. Interpretación medidas variable discreta
print("\n9. INTERPRETACIÓN HORA DEL DÍA:")
print("""
- La hora promedio de las transacciones es aproximadamente las 12:47 PM
- La mediana de 13 horas indica que la mitad de las transacciones ocurren antes de la 1 PM
- La moda es a las 12 del mediodía, siendo la hora más frecuente para compras
- El horario de ventas va desde las 7 AM hasta las 8 PM, cubriendo el horario comercial típico
- La desviación estándar de 2.85 horas muestra concentración alrededor del mediodía
""")
# Out:
# 8. MEDIDAS DE VARIABLE DISCRETA (hour_of_day):
# Media: 14.19
# Mediana: 14.00
# Moda: 10.00
# Desviación estándar: 4.23
# Mínimo: 6.00
# Máximo: 22.00
#
# 9. INTERPRETACIÓN HORA DEL DÍA:
#
# - La hora promedio de las transacciones es aproximadamente las 12:47 PM
# - La mediana de 13 horas indica que la mitad de las transacciones ocurren antes de la 1 PM
# - La moda es a las 12 del mediodía, siendo la hora más frecuente para compras
# - El horario de ventas va desde las 7 AM hasta las 8 PM, cubriendo el horario comercial típico
# - La desviación estándar de 2.85 horas muestra concentración alrededor del mediodía

# %% [markdown]
# ---
# ✅ **Interpretación**
#
# ---
#
#
# + Escriba acá sus interpretaciones

# %% [markdown]
# # Análisis Bivariado

# %% [markdown]
# En esta sección deberá elegir un par de variables que sean de interes de analizar e interpretar en el negocio los resultados obtenidos

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='coffee_name', y='hour_of_day')
plt.title('Distribución de Horas de Venta por Tipo de Café')
plt.xlabel('Tipo de Café')
plt.ylabel('Hora del Día')
plt.xticks(rotation=45)
# Mostrar todas las horas del 6 al 23
plt.yticks(range(6, 24, 1))  # el '1' es el paso

plt.show()

# %% [markdown]
# Respecto de los tipos de café más vendidos y las horas del día:
#
# ---Tendencia central (mediana de horas de venta)
#
# Las medianas se concentran entre las 12:00 y 17:00 horas, indicando que el mayor consumo ocurre entre mediodía y tarde.
#
# Hot Chocolate y Cocoa presentan las medianas más altas (16:00–17:00), con mayor preferencia vespertina.
#
# Americano y Cortado tienen las medianas más bajas (~12:00–13:00), lo que refleja consumo más temprano.
#
# ---Dispersión (caja e IQR)
#
# Latte, Espresso y Cappuccino muestran rangos amplios, con ventas distribuidas a lo largo de todo el día.
#
# Hot Chocolate y Cocoa tienen cajas más concentradas hacia la tarde, con un patrón más definido.
#
# ---Outliers
#
# No se observan valores atípicos fuertes; las ventas se distribuyen de forma continua entre las 6–7 a.m. y las 10 p.m.
#
# Comparación general
#
# Consumo matutino: Americano, Cortado y Americano with Milk.
#
# Consumo vespertino: Hot Chocolate, Cocoa y Cappuccino.
#
# Consumo equilibrado en todo el día: Latte y Espresso.
#
# ✅ Interpretación con sentido de negocio:
#
# El gráfico revela que, aunque todos los tipos de café se venden en un rango amplio de horas, existen patrones definidos: los cafés Americano, Cortado y Americano with Milk se prefieren en la mañana, mientras que Hot Chocolate, Cocoa y Cappuccino. Para el negocio, esto sugiere diseñar promociones y disponibilidad ajustadas a la hora del día para maximizar ventas y satisfacer hábitos de consumo.

# %% [markdown]
# # Análisis de simetría/asimetría

# %% [markdown]
# ## Variable elegida por el equipo que será analizada

# %%
# 11. Análisis de simetría
skewness = stats.skew(data['money'])
kurtosis = stats.kurtosis(data['money'])

print(f"\n11. ANÁLISIS DE SIMETRÍA:")
print(f"Coeficiente de asimetría: {skewness:.3f}")
print(f"Coeficiente de curtosis: {kurtosis:.3f}")

print("""
COMENTARIO DE SIMETRÍA:
El coeficiente de asimetría negativo (-0.680) indica que la distribución de los montos
tiene una cola más larga hacia la izquierda. Esto significa que hay más valores por
encima de la media que por debajo. La curtosis negativa (-0.285) sugiere que la
distribución es más plana que una distribución normal, con menos concentración de
valores alrededor de la media y colas más ligeras.
""")

# %% [markdown]
# ---
# ✅ **Interpretación**
#
# ---
#
#
# + Escriba acá sus interpretaciones

# %% [markdown]
# # Análisis de correlación

# %% [markdown]
# Acá debe incluir dos comentarios respecto del análisis de correlación

# %%
numeric_vars = data.select_dtypes(include=[np.number])
correlation_matrix = numeric_vars.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# ---
#
#
# ⌨Interpretación
#
# ---
#
# 1. La hora del día muestra una correlación muy débil con el monto de venta (0.11),
#    indicando que el momento del día tiene poca influencia en el precio pagado
#
# 2. Existe una correlación moderada positiva (0.49) entre Weekdaysort y Montisort,
#    lo cual es esperado ya que ambos representan ordenamientos temporales y están
#    naturalmente relacionados con la progresión del tiempo
#
# 3. Las correlaciones entre las demás variables numéricas son muy débiles (<0.2),
#    sugiriendo independencia entre la mayoría de las variables del dataset
